# %%
import pandas as pd
import numpy as np
np.random.seed(0)

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, classification_report

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

import xgboost as xgb
import catboost as ctb
import lightgbm as lgb

import mlflow
import mlflow.sklearn
import mlflow.xgboost

import os

pd.pandas.set_option('display.max_columns', None)
# %matplotlib inline

# %%
remote_server_uri = 'https://dagshub.com/adam.zabek/Credit_Card_Fraud_Detection.mlflow' ### insert url to remote server
mlflow.set_tracking_uri(remote_server_uri)

# %%
os.environ['MLFLOW_TRACKING_USERNAME'] = 'adam.zabek' ### insert name
os.environ['MLFLOW_TRACKING_PASSWORD'] = 'e3c5d562249c76008f52ba8e9f3e0c7b416512db' ### insert password

# %%
mlflow.set_experiment("credit_card_fraud_detection")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/02432f41fc9a40cca9546662b2719817', creation_time=1696352191511, experiment_id='0', last_update_time=1696352191511, lifecycle_stage='active', name='credit_card_fraud_detection', tags={}>

# %%
df = pd.read_csv('./df_selected.csv')

# %%
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -0.701082 -0.041687  1.680101  0.976623 -0.247020  0.348012  0.193700
# 1  0.608792  0.164138  0.109279  0.318998  0.042258 -0.060980 -0.065656
# 2 -0.700336 -0.811337  1.174270  0.270648 -0.366756  1.352655  0.643223
# 3 -0.499064 -0.109972  1.187383 -0.608355 -0.008814  0.937245  0.192079
# 4 -0.597606  0.535539  1.025470  0.287092 -0.297036  0.072873  0.481517
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.084434  0.333534  0.085688 -0.541662 -0.620391 -0.996550 -0.327050
# 1  0.072903 -0.231703 -0.153784  1.582896  1.071659  0.490735 -0.151252
# 2  0.210788 -1.381169  0.194242  0.612829  0.067156  0.719981 -0.174539
# 3  0.320843 -1.264664 -0.049713 -0.222524  0.179901  0.509483 -0.302638
# 4 -0.228725  0.747917  0.700958 -0.807922  0.541797  1.351427 -1.176125
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.603615 -0.539734  0.246646  0.028990  0.497011  0.326273 -0.024777
# 1  0.693541  0.529653 -0.136468 -0.220781 -0.178907 -0.089963 -0.311372
# 2  2.562950 -3.309216  1.317260 -0.146738 -2.780497  0.681564  0.343094
# 3 -0.691296 -1.214165 -0.812176  2.345732 -1.515112 -0.270428 -0.149093
# 4  0.190272 -0.518043 -0.281545 -0.047422  0.988165  0.530343 -0.012516
#
#         V22       V23       V24       V25       V26       V27       V28  Class
# 0  0.383483 -0.177444  0.110157  0.247059 -0.392622  0.333033 -0.065850      0
# 1 -0.881454  0.162081 -0.561503  0.321175  0.260854 -0.027154  0.043219      0
# 2  1.065068  1.457772 -1.138484 -0.628161 -0.288861 -0.144325 -0.183824      0
# 3  0.007299 -0.305465 -1.941446  1.242487 -0.460694  0.154039  0.185687      0
# 4  1.101780 -0.220709  0.232904 -0.394800  1.041677  0.550001  0.654234      0

# %%
df['Class'].value_counts()
# Out:
# 0    283253
# 1       473
# Name: Class, dtype: int64

# %%
black_list = ['Class']

# %%
def get_feats(df, black_list):
    feats = df.columns
    return [x for x in feats if x not in black_list]

# %%
def get_X(df, feats):
    
    X = df[feats]
    return X

def get_y(df, target_var):
    return df[target_var].values

# %% [markdown]
# ## Undersampling - random selection Non-Fraud observation to train model in ratio 1:4 Fraud:Non-Fraud.

# %%
def select_sample(df, target, class_name, number_of_sample):
    
    select = df[df[target] == class_name]
    selected_sample = select.sample(n = number_of_sample, replace = False)
    return selected_sample

# %%
non_fraud = select_sample(df, 'Class', 0, 1892)

# %%
fraud = select_sample(df, 'Class', 1, 473)

# %%
selected_sample = pd.concat([fraud, non_fraud])

# %%
print(selected_sample['Class'].value_counts()/len(selected_sample))
# Out:
# 0    0.8
# 1    0.2
# Name: Class, dtype: float64

# %% [markdown]
# ## Take feats to train model.

# %%
feats = get_feats(selected_sample, black_list)

# %%
X = get_X(selected_sample, feats)

# %%
y = get_y(selected_sample, target_var = 'Class')

# %% [markdown]
# ## Split data into train/test dataset.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, train_size = .8, shuffle = True, stratify = y)

# %% [markdown]
# ## Train model

# %%
model_param = [
    {
        'model_type': 'DecisionTree',
        'params': {
            'criterion': 'gini',
            'max_depth': 10,
            'random_state': 0
        }
    },
    {
        'model_type': 'RandomForest',
        'params': {
            'n_estimators': 100,
            'max_depth': 10,
            'random_state': 0
        }
    },
    {
        'model_type': 'CatBoost',
        'params': {
            #'iterations': 2000,
            'depth': 10,
            'learning_rate': 0.01,
            'n_estimators': 1000,
            'loss_function': 'Logloss',
            'early_stopping_rounds': 50,
            'random_state': 0
        }
    },
    {
        'model_type': 'LightGBM',
        'params': {
            'boosting_type': 'dart',
            'num_leaves': 20,
            'max_depth': 10,
            'n_estimators': 100,
            'learning_rate': 0.01,
            'subsample': 0.9,
            'colsample_bytree': 0.8,
            'random_state': 0
        }
    },
    {
        'model_type': 'XGBoost',
        'params': {
            'max_depth': 10,
            'learning_rate': 0.01,
            'n_estimators': 100,
            'subsample': 0.9,
            'colsample_bytree': 0.8,
            'random_state': 0
        }
    }
]

# %%
def train_models(models, model_param, X_train, X_test, y_train, y_test):
    mlflow.sklearn.autolog(disable=True)
    
    labels = ['Non Fraud', 'Fraud']
    
    for model_name in models:
        model_params  = next((params for params in model_param if params['model_type'] == model_name), None)
        
        if model_params is None:
            print(f"Model '{model_name}' not found in the parameters list.")
            continue
        
        with mlflow.start_run(run_name=f'{model_name}_Model'):
            if model_name == 'DecisionTree':
                
                mlflow.set_tag("model_name", "DT")
                mlflow.log_params(model_params)
            
                model = DecisionTreeClassifier(**model_params['params'])
                model.fit(X_train, y_train)
            
                y_pred = model.predict(X_test)
            
                auc = accuracy_score(y_test, y_pred)
                f1 = f1_score(y_test, y_pred)
                rec = recall_score(y_test, y_pred)
                prec = precision_score(y_test, y_pred)
                
                print(classification_report(y_test, y_pred, target_names=labels))
                
                mlflow.log_metric("test_auc", auc)
                mlflow.log_metric("test_f1", f1)
                mlflow.log_metric("test_rec", rec)
                mlflow.log_metric("test_prec", prec)

                mlflow.sklearn.log_model(model, f"{model_name}_Model")
            
            elif model_name == 'RandomForest':

                mlflow.set_tag("model_name", "RF")
                mlflow.log_params(model_params)
                        
                model = RandomForestClassifier(**model_params['params'])
                model.fit(X_train, y_train)
            
                y_pred = model.predict(X_test)
            
                auc = accuracy_score(y_test, y_pred)
                f1 = f1_score(y_test, y_pred)
                rec = recall_score(y_test, y_pred)
                prec = precision_score(y_test, y_pred)
                
                print(classification_report(y_test, y_pred, target_names=labels))

                mlflow.log_metric("test_auc", auc)
                mlflow.log_metric("test_f1", f1)
                mlflow.log_metric("test_rec", rec)
                mlflow.log_metric("test_prec", prec)

                mlflow.sklearn.log_model(model, f"{model_name}_Model")
            
            elif model_name == 'CatBoost':

                mlflow.set_tag("model_name", "CB")
                mlflow.log_params(model_params)
                                    
                model = ctb.CatBoostClassifier(**model_params['params'])
                model.fit(X_train, y_train)
            
                y_pred = model.predict(X_test)
            
                auc = accuracy_score(y_test, y_pred)
                f1 = f1_score(y_test, y_pred)
                rec = recall_score(y_test, y_pred)
                prec = precision_score(y_test, y_pred)
                
                print(classification_report(y_test, y_pred, target_names=labels))
                
                mlflow.log_metric("test_auc", auc)
                mlflow.log_metric("test_f1", f1)
                mlflow.log_metric("test_rec", rec)
                mlflow.log_metric("test_prec", prec)

                mlflow.sklearn.log_model(model, f"{model_name}_Model")
            
            elif model_name == 'LightGBM':

                mlflow.set_tag("model_name", "LGB")
                mlflow.log_params(model_params)
                                    
                model = lgb.LGBMClassifier(**model_params['params'])
                model.fit(X_train, y_train)
            
                y_pred = model.predict(X_test)
            
                auc = accuracy_score(y_test, y_pred)
                f1 = f1_score(y_test, y_pred)
                rec = recall_score(y_test, y_pred)
                prec = precision_score(y_test, y_pred)
                
                print(classification_report(y_test, y_pred, target_names=labels))
                
                mlflow.log_metric("test_auc", auc)
                mlflow.log_metric("test_f1", f1)
                mlflow.log_metric("test_rec", rec)
                mlflow.log_metric("test_prec", prec)

                mlflow.sklearn.log_model(model, f"{model_name}_Model")
            
            elif model_name == 'XGBoost':

                mlflow.set_tag("model_name", "XGB")
                mlflow.log_params(model_params)
                                    
                model = xgb.XGBClassifier(**model_params['params'])
                model.fit(X_train, y_train)
            
                y_pred = model.predict(X_test)
            
                auc = accuracy_score(y_test, y_pred)
                f1 = f1_score(y_test, y_pred)
                rec = recall_score(y_test, y_pred)
                prec = precision_score(y_test, y_pred)
                
                print(classification_report(y_test, y_pred, target_names=labels))
                
                mlflow.log_metric("test_auc", auc)
                mlflow.log_metric("test_f1", f1)
                mlflow.log_metric("test_rec", rec)
                mlflow.log_metric("test_prec", prec)

                mlflow.sklearn.log_model(model, f"{model_name}_Model")

# %%
models = ['DecisionTree','RandomForest','CatBoost','LightGBM','XGBoost']
train_models(models, model_param, X_train, X_test, y_train, y_test)
# Out:
#               precision    recall  f1-score   support
#
#    Non Fraud       0.96      0.97      0.97       378
#        Fraud       0.89      0.85      0.87        95
#
#     accuracy                           0.95       473
#    macro avg       0.93      0.91      0.92       473
# weighted avg       0.95      0.95      0.95       473
#
#               precision    recall  f1-score   support
#
#    Non Fraud       0.96      1.00      0.98       378
#        Fraud       0.99      0.82      0.90        95
#
#     accuracy                           0.96       473
#    macro avg       0.97      0.91      0.94       473
# weighted avg       0.96      0.96      0.96       473
#
# 0:	learn: 0.6762895	total: 58.3ms	remaining: 58.3s
# 1:	learn: 0.6602934	total: 122ms	remaining: 1m
# 2:	learn: 0.6442081	total: 188ms	remaining: 1m 2s
# 3:	learn: 0.6282370	total: 252ms	remaining: 1m 2s
# 4:	learn: 0.6138506	total: 310ms	remaining: 1m 1s
# 5:	learn: 0.5984205	total: 370ms	remaining: 1m 1s
# 6:	learn: 0.5844199	total: 437ms	remaining: 1m 2s
# 7:	learn: 0.5715737	total: 504ms	remaining: 1m 2s
# 8:	learn: 0.5597194	total: 573ms	remaining: 1m 3s
# 9:	learn: 0.5455941	total: 642ms	remaining: 1m 3s
# 10:	learn: 0.5325764	total: 712ms	remaining: 1m 4s
# 11:	learn: 0.5185227	total: 781ms	remaining: 1m 4s
# 12:	learn: 0.5066104	total: 847ms	remaining: 1m 4s
# 13:	learn: 0.4947530	total: 865ms	remaining: 1m
# 14:	learn: 0.4839822	total: 932ms	remaining: 1m 1s
# 15:	learn: 0.4730597	total: 999ms	remaining: 1m 1s
# 16:	learn: 0.4632955	total: 1.06s	remaining: 1m 1s
# 17:	learn: 0.4529190	total: 1.13s	remaining: 1m 1s
# 18:	learn: 0.4441159	total: 1.2s	remaining: 1m 1s
# 19:	learn: 0.4341892	total: 1.26s	remaining: 1m 1s
# 20:	learn: 0.4256446	total: 1.33s	remaining: 1m 1s
# 21:	learn: 0.4163636	total: 1.39s	remaining: 1m 1s
# 22:	learn: 0.4076846	total: 1.45s	remaining: 1m 1s
# 23:	learn: 0.3987132	total: 1.51s	remaining: 1m 1s
# 24:	learn: 0.3901061	total: 1.57s	remaining: 1m 1s
# 25:	learn: 0.3812842	total: 1.63s	remaining: 1m 1s
# 26:	learn: 0.3735735	total: 1.7s	remaining: 1m 1s
# 27:	learn: 0.3656499	total: 1.76s	remaining: 1m
# 28:	learn: 0.3574381	total: 1.82s	remaining: 1m
# 29:	learn: 0.3511223	total: 1.88s	remaining: 1m
# 30:	learn: 0.3447428	total: 1.95s	remaining: 1m
# 31:	learn: 0.3391393	total: 2.01s	remaining: 1m
# 32:	learn: 0.3328715	total: 2.07s	remaining: 1m
# 33:	learn: 0.3256782	total: 2.13s	remaining: 1m
# 34:	learn: 0.3191230	total: 2.2s	remaining: 1m
# 35:	learn: 0.3129094	total: 2.26s	remaining: 1m
# 36:	learn: 0.3072232	total: 2.32s	remaining: 1m
# 37:	learn: 0.3016512	total: 2.38s	remaining: 1m
# 38:	learn: 0.2965828	total: 2.45s	remaining: 1m
# 39:	learn: 0.2909614	total: 2.51s	remaining: 1m
# 40:	learn: 0.2850542	total: 2.59s	remaining: 1m
# 41:	learn: 0.2802368	total: 2.65s	remaining: 1m
# 42:	learn: 0.2750852	total: 2.71s	remaining: 1m
# 43:	learn: 0.2699718	total: 2.78s	remaining: 1m
# 44:	learn: 0.2654504	total: 2.84s	remaining: 1m
# 45:	learn: 0.2605946	total: 2.9s	remaining: 1m
# 789:	learn: 0.0096338	total: 59.7s	remaining: 15.9s
# 790:	learn: 0.0096186	total: 59.8s	remaining: 15.8s
# 791:	learn: 0.0096042	total: 59.9s	remaining: 15.7s
# 792:	learn: 0.0095887	total: 60s	remaining: 15.6s
# 793:	learn: 0.0095692	total: 1m	remaining: 15.6s
# 794:	learn: 0.0095495	total: 1m	remaining: 15.5s
# 795:	learn: 0.0095377	total: 1m	remaining: 15.4s
# 796:	learn: 0.0095228	total: 1m	remaining: 15.3s
# 797:	learn: 0.0094987	total: 1m	remaining: 15.3s
# 798:	learn: 0.0094824	total: 1m	remaining: 15.2s
# 799:	learn: 0.0094605	total: 1m	remaining: 15.1s
# 800:	learn: 0.0094427	total: 1m	remaining: 15s
# 801:	learn: 0.0094207	total: 1m	remaining: 15s
# 802:	learn: 0.0094006	total: 1m	remaining: 14.9s
# 803:	learn: 0.0093832	total: 1m	remaining: 14.8s
# 804:	learn: 0.0093640	total: 1m	remaining: 14.7s
# 805:	learn: 0.0093488	total: 1m	remaining: 14.7s
# 806:	learn: 0.0093312	total: 1m 1s	remaining: 14.6s
# 807:	learn: 0.0093135	total: 1m 1s	remaining: 14.5s
# 808:	learn: 0.0092920	total: 1m 1s	remaining: 14.4s
# 809:	learn: 0.0092693	total: 1m 1s	remaining: 14.4s
# 810:	learn: 0.0092485	total: 1m 1s	remaining: 14.3s
# 811:	learn: 0.0092355	total: 1m 1s	remaining: 14.2s
# 812:	learn: 0.0092174	total: 1m 1s	remaining: 14.1s
# 813:	learn: 0.0091939	total: 1m 1s	remaining: 14.1s
# 814:	learn: 0.0091794	total: 1m 1s	remaining: 14s
# 815:	learn: 0.0091598	total: 1m 1s	remaining: 13.9s
# 816:	learn: 0.0091453	total: 1m 1s	remaining: 13.8s
# 817:	learn: 0.0091305	total: 1m 1s	remaining: 13.8s
# 818:	learn: 0.0091101	total: 1m 1s	remaining: 13.7s
# 819:	learn: 0.0090955	total: 1m 1s	remaining: 13.6s
# 820:	learn: 0.0090839	total: 1m 2s	remaining: 13.5s
# 821:	learn: 0.0090660	total: 1m 2s	remaining: 13.4s
# 822:	learn: 0.0090536	total: 1m 2s	remaining: 13.4s
# 823:	learn: 0.0090413	total: 1m 2s	remaining: 13.3s
# 824:	learn: 0.0090263	total: 1m 2s	remaining: 13.2s
# 825:	learn: 0.0090148	total: 1m 2s	remaining: 13.1s
# 826:	learn: 0.0089940	total: 1m 2s	remaining: 13.1s
# 827:	learn: 0.0089796	total: 1m 2s	remaining: 13s
# 828:	learn: 0.0089666	total: 1m 2s	remaining: 12.9s
# 829:	learn: 0.0089541	total: 1m 2s	remaining: 12.8s
# 830:	learn: 0.0089389	total: 1m 2s	remaining: 12.8s
# 831:	learn: 0.0089163	total: 1m 2s	remaining: 12.7s
# 832:	learn: 0.0088981	total: 1m 2s	remaining: 12.6s
# 833:	learn: 0.0088865	total: 1m 3s	remaining: 12.5s
# 834:	learn: 0.0088748	total: 1m 3s	remaining: 12.5s
# 835:	learn: 0.0088580	total: 1m 3s	remaining: 12.4s
# 836:	learn: 0.0088454	total: 1m 3s	remaining: 12.3s
# 837:	learn: 0.0088304	total: 1m 3s	remaining: 12.2s
# 838:	learn: 0.0088116	total: 1m 3s	remaining: 12.2s
# 839:	learn: 0.0087999	total: 1m 3s	remaining: 12.1s
# 840:	learn: 0.0087904	total: 1m 3s	remaining: 12s
# 841:	learn: 0.0087731	total: 1m 3s	remaining: 11.9s
# 842:	learn: 0.0087531	total: 1m 3s	remaining: 11.9s
# 843:	learn: 0.0087396	total: 1m 3s	remaining: 11.8s
# 844:	learn: 0.0087259	total: 1m 3s	remaining: 11.7s
# 845:	learn: 0.0087036	total: 1m 3s	remaining: 11.6s
# 846:	learn: 0.0086867	total: 1m 3s	remaining: 11.6s
# 847:	learn: 0.0086682	total: 1m 4s	remaining: 11.5s
# 848:	learn: 0.0086586	total: 1m 4s	remaining: 11.4s
# 849:	learn: 0.0086440	total: 1m 4s	remaining: 11.3s
# 850:	learn: 0.0086335	total: 1m 4s	remaining: 11.3s
# 851:	learn: 0.0086135	total: 1m 4s	remaining: 11.2s
# 852:	learn: 0.0085995	total: 1m 4s	remaining: 11.1s
# 853:	learn: 0.0085834	total: 1m 4s	remaining: 11s
# 854:	learn: 0.0085667	total: 1m 4s	remaining: 11s
# 855:	learn: 0.0085507	total: 1m 4s	remaining: 10.9s
# 856:	learn: 0.0085365	total: 1m 4s	remaining: 10.8s
# 857:	learn: 0.0085189	total: 1m 4s	remaining: 10.7s
# 858:	learn: 0.0085063	total: 1m 4s	remaining: 10.6s
# 859:	learn: 0.0084905	total: 1m 4s	remaining: 10.6s
# 860:	learn: 0.0084723	total: 1m 5s	remaining: 10.5s
# 861:	learn: 0.0084613	total: 1m 5s	remaining: 10.4s
# 862:	learn: 0.0084436	total: 1m 5s	remaining: 10.3s
# 863:	learn: 0.0084273	total: 1m 5s	remaining: 10.3s
# 864:	learn: 0.0084120	total: 1m 5s	remaining: 10.2s
# 865:	learn: 0.0084002	total: 1m 5s	remaining: 10.1s
# 866:	learn: 0.0083852	total: 1m 5s	remaining: 10s
# 867:	learn: 0.0083666	total: 1m 5s	remaining: 9.97s
# 868:	learn: 0.0083522	total: 1m 5s	remaining: 9.9s
# 869:	learn: 0.0083382	total: 1m 5s	remaining: 9.82s
# 870:	learn: 0.0083194	total: 1m 5s	remaining: 9.75s
# 871:	learn: 0.0083003	total: 1m 5s	remaining: 9.67s
# 872:	learn: 0.0082852	total: 1m 5s	remaining: 9.6s
# 873:	learn: 0.0082719	total: 1m 6s	remaining: 9.52s
# 874:	learn: 0.0082562	total: 1m 6s	remaining: 9.45s
# 875:	learn: 0.0082413	total: 1m 6s	remaining: 9.37s
# 876:	learn: 0.0082313	total: 1m 6s	remaining: 9.3s
# 877:	learn: 0.0082205	total: 1m 6s	remaining: 9.22s
# 878:	learn: 0.0082077	total: 1m 6s	remaining: 9.15s
# 879:	learn: 0.0081919	total: 1m 6s	remaining: 9.07s
# 880:	learn: 0.0081805	total: 1m 6s	remaining: 8.99s
# 881:	learn: 0.0081669	total: 1m 6s	remaining: 8.92s
# 882:	learn: 0.0081513	total: 1m 6s	remaining: 8.84s
# 883:	learn: 0.0081394	total: 1m 6s	remaining: 8.77s
# 884:	learn: 0.0081284	total: 1m 6s	remaining: 8.69s
# 885:	learn: 0.0081178	total: 1m 6s	remaining: 8.62s
# 886:	learn: 0.0081030	total: 1m 7s	remaining: 8.54s
# 887:	learn: 0.0080898	total: 1m 7s	remaining: 8.47s
# 888:	learn: 0.0080819	total: 1m 7s	remaining: 8.39s
# 889:	learn: 0.0080664	total: 1m 7s	remaining: 8.31s
# 890:	learn: 0.0080530	total: 1m 7s	remaining: 8.24s
# 891:	learn: 0.0080415	total: 1m 7s	remaining: 8.16s
# 892:	learn: 0.0080284	total: 1m 7s	remaining: 8.09s
# 893:	learn: 0.0080189	total: 1m 7s	remaining: 8.01s
# 894:	learn: 0.0080034	total: 1m 7s	remaining: 7.93s
# 895:	learn: 0.0079933	total: 1m 7s	remaining: 7.86s
# 896:	learn: 0.0079847	total: 1m 7s	remaining: 7.78s
# 897:	learn: 0.0079738	total: 1m 7s	remaining: 7.71s
# 898:	learn: 0.0079662	total: 1m 7s	remaining: 7.63s
# 899:	learn: 0.0079538	total: 1m 8s	remaining: 7.56s
# 900:	learn: 0.0079436	total: 1m 8s	remaining: 7.48s
# 901:	learn: 0.0079281	total: 1m 8s	remaining: 7.4s
# 902:	learn: 0.0079098	total: 1m 8s	remaining: 7.33s
# 903:	learn: 0.0078937	total: 1m 8s	remaining: 7.25s
# 904:	learn: 0.0078838	total: 1m 8s	remaining: 7.18s
# 905:	learn: 0.0078672	total: 1m 8s	remaining: 7.1s
# 906:	learn: 0.0078558	total: 1m 8s	remaining: 7.03s
# 907:	learn: 0.0078395	total: 1m 8s	remaining: 6.95s
# 908:	learn: 0.0078229	total: 1m 8s	remaining: 6.87s
# 909:	learn: 0.0078088	total: 1m 8s	remaining: 6.8s
# 910:	learn: 0.0077950	total: 1m 8s	remaining: 6.72s
# 911:	learn: 0.0077841	total: 1m 8s	remaining: 6.64s
# 912:	learn: 0.0077712	total: 1m 8s	remaining: 6.57s
# 913:	learn: 0.0077567	total: 1m 9s	remaining: 6.49s
# 914:	learn: 0.0077446	total: 1m 9s	remaining: 6.42s
# 915:	learn: 0.0077325	total: 1m 9s	remaining: 6.34s
# 916:	learn: 0.0077226	total: 1m 9s	remaining: 6.27s
# 917:	learn: 0.0077091	total: 1m 9s	remaining: 6.19s
# 918:	learn: 0.0076926	total: 1m 9s	remaining: 6.12s
# 919:	learn: 0.0076753	total: 1m 9s	remaining: 6.04s
# 920:	learn: 0.0076667	total: 1m 9s	remaining: 5.97s
# 921:	learn: 0.0076519	total: 1m 9s	remaining: 5.89s
# 922:	learn: 0.0076408	total: 1m 9s	remaining: 5.82s
# 923:	learn: 0.0076309	total: 1m 9s	remaining: 5.74s
# 924:	learn: 0.0076154	total: 1m 9s	remaining: 5.66s
# 925:	learn: 0.0076011	total: 1m 9s	remaining: 5.59s
# 926:	learn: 0.0075910	total: 1m 10s	remaining: 5.51s
# 927:	learn: 0.0075822	total: 1m 10s	remaining: 5.44s
# 928:	learn: 0.0075669	total: 1m 10s	remaining: 5.36s
# 929:	learn: 0.0075579	total: 1m 10s	remaining: 5.29s
# 930:	learn: 0.0075471	total: 1m 10s	remaining: 5.21s
# 931:	learn: 0.0075328	total: 1m 10s	remaining: 5.13s
# 932:	learn: 0.0075178	total: 1m 10s	remaining: 5.06s
# 933:	learn: 0.0075093	total: 1m 10s	remaining: 4.98s
# 934:	learn: 0.0075039	total: 1m 10s	remaining: 4.91s
# 935:	learn: 0.0074910	total: 1m 10s	remaining: 4.83s
# 936:	learn: 0.0074779	total: 1m 10s	remaining: 4.76s
# 937:	learn: 0.0074720	total: 1m 10s	remaining: 4.68s
# 938:	learn: 0.0074582	total: 1m 10s	remaining: 4.61s
# 939:	learn: 0.0074454	total: 1m 10s	remaining: 4.53s
# 940:	learn: 0.0074353	total: 1m 11s	remaining: 4.46s
# 941:	learn: 0.0074236	total: 1m 11s	remaining: 4.38s
# 942:	learn: 0.0074139	total: 1m 11s	remaining: 4.3s
# 943:	learn: 0.0074036	total: 1m 11s	remaining: 4.23s
# 944:	learn: 0.0073909	total: 1m 11s	remaining: 4.15s
# 945:	learn: 0.0073807	total: 1m 11s	remaining: 4.08s
# 946:	learn: 0.0073687	total: 1m 11s	remaining: 4s
# 947:	learn: 0.0073600	total: 1m 11s	remaining: 3.93s
# 948:	learn: 0.0073495	total: 1m 11s	remaining: 3.85s
# 949:	learn: 0.0073385	total: 1m 11s	remaining: 3.77s
# 950:	learn: 0.0073280	total: 1m 11s	remaining: 3.7s
# 951:	learn: 0.0073159	total: 1m 11s	remaining: 3.62s
# 952:	learn: 0.0073009	total: 1m 11s	remaining: 3.55s
# 953:	learn: 0.0072887	total: 1m 12s	remaining: 3.47s
# 954:	learn: 0.0072767	total: 1m 12s	remaining: 3.4s
# 955:	learn: 0.0072651	total: 1m 12s	remaining: 3.32s
# 956:	learn: 0.0072537	total: 1m 12s	remaining: 3.25s
# 957:	learn: 0.0072414	total: 1m 12s	remaining: 3.17s
# 958:	learn: 0.0072296	total: 1m 12s	remaining: 3.09s
# 959:	learn: 0.0072193	total: 1m 12s	remaining: 3.02s
# 960:	learn: 0.0072046	total: 1m 12s	remaining: 2.94s
# 961:	learn: 0.0071896	total: 1m 12s	remaining: 2.87s
# 962:	learn: 0.0071808	total: 1m 12s	remaining: 2.79s
# 963:	learn: 0.0071690	total: 1m 12s	remaining: 2.72s
# 964:	learn: 0.0071595	total: 1m 12s	remaining: 2.64s
# 965:	learn: 0.0071501	total: 1m 12s	remaining: 2.56s
# 966:	learn: 0.0071393	total: 1m 12s	remaining: 2.49s
# 967:	learn: 0.0071306	total: 1m 13s	remaining: 2.41s
# 968:	learn: 0.0071174	total: 1m 13s	remaining: 2.34s
# 969:	learn: 0.0071073	total: 1m 13s	remaining: 2.26s
# 970:	learn: 0.0070946	total: 1m 13s	remaining: 2.19s
# 971:	learn: 0.0070833	total: 1m 13s	remaining: 2.11s
# 972:	learn: 0.0070762	total: 1m 13s	remaining: 2.04s
# 973:	learn: 0.0070676	total: 1m 13s	remaining: 1.96s
# 974:	learn: 0.0070603	total: 1m 13s	remaining: 1.89s
# 975:	learn: 0.0070474	total: 1m 13s	remaining: 1.81s
# 976:	learn: 0.0070359	total: 1m 13s	remaining: 1.73s
# 977:	learn: 0.0070242	total: 1m 13s	remaining: 1.66s
# 978:	learn: 0.0070146	total: 1m 13s	remaining: 1.58s
# 979:	learn: 0.0070057	total: 1m 13s	remaining: 1.51s
# 980:	learn: 0.0069951	total: 1m 13s	remaining: 1.43s
# 981:	learn: 0.0069828	total: 1m 14s	remaining: 1.36s
# 982:	learn: 0.0069726	total: 1m 14s	remaining: 1.28s
# 983:	learn: 0.0069600	total: 1m 14s	remaining: 1.21s
# 984:	learn: 0.0069494	total: 1m 14s	remaining: 1.13s
# 985:	learn: 0.0069389	total: 1m 14s	remaining: 1.05s
# 986:	learn: 0.0069252	total: 1m 14s	remaining: 980ms
# 987:	learn: 0.0069143	total: 1m 14s	remaining: 905ms
# 988:	learn: 0.0069044	total: 1m 14s	remaining: 829ms
# 989:	learn: 0.0068963	total: 1m 14s	remaining: 754ms
# 990:	learn: 0.0068870	total: 1m 14s	remaining: 679ms
# 991:	learn: 0.0068785	total: 1m 14s	remaining: 603ms
# 992:	learn: 0.0068702	total: 1m 14s	remaining: 528ms
# 993:	learn: 0.0068627	total: 1m 14s	remaining: 452ms
# 994:	learn: 0.0068480	total: 1m 15s	remaining: 377ms
# 995:	learn: 0.0068420	total: 1m 15s	remaining: 302ms
# 996:	learn: 0.0068340	total: 1m 15s	remaining: 226ms
# 997:	learn: 0.0068238	total: 1m 15s	remaining: 151ms
# 998:	learn: 0.0068102	total: 1m 15s	remaining: 75.4ms
# 999:	learn: 0.0067994	total: 1m 15s	remaining: 0us
#               precision    recall  f1-score   support
#
#    Non Fraud       0.96      1.00      0.98       378
#        Fraud       1.00      0.84      0.91        95
#
#     accuracy                           0.97       473
#    macro avg       0.98      0.92      0.95       473
# weighted avg       0.97      0.97      0.97       473
#
# [LightGBM] [Info] Number of positive: 378, number of negative: 1514
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000596 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7140
# [LightGBM] [Info] Number of data points in the train set: 1892, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.199789 -> initscore=-1.387616
# [LightGBM] [Info] Start training from score -1.387616
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#               precision    recall  f1-score   support
#
#    Non Fraud       0.95      1.00      0.97       378
#        Fraud       1.00      0.79      0.88        95
#
#     accuracy                           0.96       473
#    macro avg       0.97      0.89      0.93       473
# weighted avg       0.96      0.96      0.96       473
#
#               precision    recall  f1-score   support
#
#    Non Fraud       0.95      1.00      0.98       378
#        Fraud       1.00      0.80      0.89        95
#
#     accuracy                           0.96       473
#    macro avg       0.98      0.90      0.93       473
# weighted avg       0.96      0.96      0.96       473
